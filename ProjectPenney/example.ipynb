# %%
# install/import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

import src.helpers
from importlib import reload
reload(src.helpers);

import src.datagen
from importlib import reload
reload(src.datagen);

import src.penney
reload(src.penney);

from src.datagen import datagen
from src.penney import Penney

# %%
# initialize datagen with a seed, for example 27
datagen = datagen(27)

# %%
# create some decks
datagen.create_decks(10000)
# Out:
# create_decks ran for 0.029775 seconds.

# %%
# what if i want to see those decks?
decks = datagen.load_decks() # this loads all of the decks generated with the seed this instance is running on
# Out:
# load_decks ran for 0.002485 seconds.

# %%
# how many decks do i have?
len(decks)
# Out:
# 11500

# %%
# let's say you want to start completely over...
#datagen.delete_data() will delete all of the decks and the .json file that is storing the state of the seed

# %%
# alright, let's initialize penney
penney = Penney()
# Out:
# load_decks ran for 0.002384 seconds.

# %%
# now i want to simulate the game over all of the decks i've generated...this may take a bit
game_sim = penney.game_sim()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # now i want to simulate the game over all of the decks i've generated...this may take a bit
# ----> 2 game_sim = penney.game_sim()
#
# File ~\OneDrive\Documents\GitHub\jackwardphillips.github.io\School\AutomationWorkflows\ProjectPenney\src\helpers.py:22, in debugger_factory.<locals>.debugger.<locals>.wrapper(*args, **kwargs)
#      20 if TIMER:
#      21     t0 = dt.now()
# ---> 22     results = func(*args, **kwargs)
#      23     wrapper.last_execution_time = (dt.now() - t0).total_seconds()
#      24     print(f'{func.__name__} ran for {wrapper.last_execution_time} seconds.')
#
# File ~\OneDrive\Documents\GitHub\jackwardphillips.github.io\School\AutomationWorkflows\ProjectPenney\src\penney.py:90, in Penney.game_sim(self)
#      88 for j, p2 in enumerate(self.sequences):
# ...

# %%
# the dataframe with the results is now stored in game_sim, now let's visualize it
penney.heatmap(game_sim)
# Out:
# heatmap ran for 0.123057 seconds.

# %%
# you've succesfully used the repository!
