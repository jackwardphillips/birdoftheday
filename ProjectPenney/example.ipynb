# %%
# install/import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

import src.helpers
from importlib import reload
reload(src.helpers);

import src.datagen
from importlib import reload
reload(src.datagen);

import src.penney
reload(src.penney);

from src.datagen import datagen
from src.penney import Penney

# %%
penney = Penney()
# Out:
# Loaded 300 decks.
# load_decks ran for 0.000999 seconds.

# %%
penney.showdown()
# Out:
# 0
# 596
# 4
# 154
# 384
# 62
# 240
# 266
# 94
# 8
# 572
# 20
# 128
# 382
# 90
# 106
# 424
# 70
# 178
# 176
# 246
# 596
# 0
# 4
# 264
# 232
# 104
# 562
# 20
# 18
# 38
# 524
# 38
# 294
# 226
# 80
# 270
# 256
# 74
# 458
# 74
# 68
# 384
# 154
# 62
# 232
# 264
# 104
# 56
# 492
# 52
# 74
# 476
# 50
# 252
# 226
# 122
# 264
# 270
# 66
# 390
# 126
# 84
# 266
# 240
# 94
# 20
# 562
# 18
# 492
# 56
# 52
# 258
# 236
# 106
# 494
# 48
# 58
# 544
# 24
# 32
# 570
# 8
# 22
# 572
# 8
# 20
# 524
# 38
# 38
# 476
# 74
# 50
# 236
# 258
# 106
# 492
# 74
# 34
# 16
# 550
# 34
# 250
# 266
# 84
# 382
# 128
# 90
# 226
# 294
# 80
# 226
# 252
# 122
# 48
# 494
# 58
# 74
# 492
# 34
# 240
# 284
# 76
# 370
# 154
# 76
# 424
# 106
# 70
# 256
# 270
# 74
# 270
# 264
# 66
# 24
# 544
# 32
# 550
# 16
# 34
# 284
# 240
# 76
# 592
# 0
# 8
# 176
# 178
# 246
# 74
# 458
# 68
# 126
# 390
# 84
# 8
# 570
# 22
# 266
# 250
# 84
# 154
# 370
# 76
# 0
# 592
# 8
# heatmap ran for 0.299073 seconds.
# showdown ran for 0.739054 seconds.

# %%
# initialize datagen with a seed, for example 27
datagen = datagen(27)

# %%
# create some decks
datagen.create_decks(100)
# Out:
# create_decks ran for 0.016518 seconds.

# %%
# what if i want to see those decks?
decks = datagen.load_decks() # this loads all of the decks generated with the seed this instance is running on
# Out:
# Loaded 300 decks.
# load_decks ran for 0.01301 seconds.

# %%
# let's say you want to start completely over...
datagen.delete_data() #will delete all of the decks and the .json file that is storing the state of the seed
# Out:
# Are you sure you want to delete data/decks_27.npy? This cannot be undone. yes
# File 'data/decks_27.npy' deleted successfully.
# Are you sure you want to delete data/state_27.json? This cannot be undone. yes
# File 'data/state_27.json' deleted successfully.
# delete_data ran for 2.791089 seconds.

# %%
# alright, let's initialize penney
penney = Penney()
# Out:
# Loaded 300 decks.
# load_decks ran for 0.001003 seconds.

# %%
# now i want to simulate the game over all of the decks i've generated...this may take a bit
game_sim = penney.showdown()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # now i want to simulate the game over all of the decks i've generated...this may take a bit
# ----> 2 game_sim = penney.showdown()
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\src\helpers.py:24, in debugger_factory.<locals>.debugger.<locals>.wrapper(*args, **kwargs)
#      22 if TIMER:
#      23     t0 = dt.now()
# ---> 24     results = func(*args, **kwargs)
#      25     wrapper.last_execution_time = (dt.now() - t0).total_seconds()
#      26     print(f'{func.__name__} ran for {wrapper.last_execution_time} seconds.')
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\src\penney.py:124, in Penney.showdown(self, heatmap)
#     122 else:
#     123     p1_wins, p2_wins, draws = self.matchup(p1, p2, self.decks)
# --> 124     p1win_df.iloc[i, j] += p1_wins
#     125     p2win_df.iloc[i, j] += p2_wins
#     126     draw_df.iloc[i, j] += draws
#
# TypeError: can only concatenate str (not "int") to str

# %%
# the dataframe with the results is now stored in game_sim, now let's visualize it
penney.heatmap(game_sim)
# Out:
# C:\Users\doobs\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\doobs\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# heatmap ran for 0.396306 seconds.

# %%
# you've succesfully used the repository!
