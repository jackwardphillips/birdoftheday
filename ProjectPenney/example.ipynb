# %%
# install/import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

import src.helpers
from importlib import reload
reload(src.helpers);

import src.datagen
from importlib import reload
reload(src.datagen);

import src.penney
reload(src.penney);

from src.datagen import datagen
from src.penney import Penney

# %%
# initialize datagen with a seed, for example 27
datagen = datagen(27)

# %%
# create some decks
datagen.create_decks(1000000)
# Out:
# create_decks ran for 1.340326 seconds.

# %%
# what if i want to see those decks?
decks = datagen.load_decks() # this loads all of the decks generated with the seed this instance is running on
# Out:
# Loaded 1000000 decks.
# load_decks ran for 0.14277 seconds.

# %%
# let's say you want to start completely over...
#datagen.delete_data() #will delete all of the decks and the .json file that is storing the state of the seed

# %%
# alright, let's initialize penney
penney = Penney()
# Out:
# Loaded 1000000 decks.
# load_decks ran for 0.186724 seconds.

# %%
# now i want to simulate the game over all of the decks i've generated...this may take a bit
game_sim = penney.game_sim()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 2
#       1 # now i want to simulate the game over all of the decks i've generated...this may take a bit
# ----> 2 game_sim = penney.game_sim()
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\src\helpers.py:24, in debugger_factory.<locals>.debugger.<locals>.wrapper(*args, **kwargs)
#      22 if TIMER:
#      23     t0 = dt.now()
# ---> 24     results = func(*args, **kwargs)
#      25     wrapper.last_execution_time = (dt.now() - t0).total_seconds()
#      26     print(f'{func.__name__} ran for {wrapper.last_execution_time} seconds.')
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\src\penney.py:76, in Penney.game_sim(self)
#      74 for j, p2 in enumerate(self.sequences):
#      75     if i != j: # don't test sequences against themselves
# ---> 76         p1_wins, p2_wins = self.game(p1, p2, self.decks[k])
#      77         if p1_wins + p2_wins == 0:
#      78             win_matrix[i, j] = 0
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\src\penney.py:50, in Penney.game(self, p1, p2, deck)
#      47 deck_length = len(deck)
#      49 while i < deck_length - 2:
# ---> 50     if np.array_equal(deck[i:i+3], p1):
#      51         p1_wins += 1
#      52         i += 3 # player one win, "clear" the hand
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\numpy\_core\numeric.py:2541, in array_equal(a1, a2, equal_nan)
#    2539     return False
#    2540 if not equal_nan:
# -> 2541     return builtins.bool((asanyarray(a1 == a2)).all())
#    2543 if a1 is a2:
#    2544     # nan will compare equal so an array will compare equal to itself.
#    2545     return True
#
# File ~\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\numpy\_core\_methods.py:67, in _all(a, axis, dtype, out, keepdims, where)
#      64         return umr_any(a, axis, dtype, out, keepdims)
#      65     return umr_any(a, axis, dtype, out, keepdims, where=where)
# ---> 67 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      68     # By default, return a boolean for any and all
#      69     if dtype is None:
#      70         dtype = bool_dt
#
# KeyboardInterrupt:

# %%
# the dataframe with the results is now stored in game_sim, now let's visualize it
penney.heatmap(game_sim)
# Out:
# C:\Users\doobs\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\doobs\OneDrive\Documents\GitHub\AutomationWorkflows\ProjectPenney\.venv\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# heatmap ran for 0.396306 seconds.

# %%
# you've succesfully used the repository!
